# %%
import pandas as pd                                  
import numpy as np                                    
from sklearn.model_selection import train_test_split 
from sklearn.dummy import DummyRegressor               
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_absolute_error, r2_score

# %%
df = pd.read_csv("sample_sales_data_FEATURES.csv")
df.head()
# Out:
#    order_id  order_date     category region month        sales   quantity  \
# 0         1  2026-06-04  Electronics   East   Feb  1233.829375   8.956522
# 1         2  2026-04-02  Electronics  North   Feb  1233.829375   8.956522
# 2         3  2026-06-23         Toys  South   Apr  1233.829375   6.000000
# 3         4  2026-03-05     Clothing   East   Jan  1233.829375  12.000000
# 4         5  2026-03-26  Electronics   West   May   462.000000   3.000000
#
#   customer_name  total_spend  is_weekend  category_avg_spend  high_value_order
# 0           Kim  11050.81962       False        11495.126526             False
# 1       Unknown  11050.81962       False        11495.126526             False
# 2         Priya   7402.97625       False        10192.251932             False
# 3           Kim  14805.95250       False        11478.106721              True
# 4       Unknown   1386.00000       False        11495.126526             False

# %%
X = df[["quantity"]]
Y = df["sales"]
X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y,                                               
    test_size=0.2,                                       
    random_state=42                            
)

# %%
baseline_model = DummyRegressor(strategy="mean")         
baseline_model.fit(X_train, Y_train)                      
baseline_preds = baseline_model.predict(X_test)

# %%
print("Baseline MAE: ", mean_absolute_error(Y_test, baseline_preds))
print("Baseline R2: ", r2_score(Y_test, baseline_preds))
# Out:
# Baseline MAE:  407.73041015625006
# Baseline R2:  -0.007145603060149108
